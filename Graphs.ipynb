# %%
import pandas as pd

# %%
df = pd.read_csv('Gaming_Data_Cleaned_Draft1')
df = df.drop(columns='Unnamed: 0')

# %%
df.groupby('Console').count()
# Out:
#          Game Title  Weekly Sales  All Time Sales  Weeks Out  Genre  \
# Console
# 3DS             212           212             212        212    212
# NS              695           695             695        695    695
# PC               15            15              15         15     15
# PS3               3             3               3          3      3
# PS4            1520          1520            1520       1520   1520
# PSV               7             7               7          7      7
# WiiU             10            10              10         10     10
# X360              2             2               2          2      2
# XOne            558           558             558        558    558
#
#          Publisher  Count
# Console
# 3DS            212    212
# NS             695    695
# PC              15     15
# PS3              3      3
# PS4           1520   1520
# PSV              7      7
# WiiU            10     10
# X360             2      2
# ...
